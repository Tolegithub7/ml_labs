# %% [markdown]
# <a href="https://colab.research.google.com/github/Tolegithub7/ml_labs/blob/main/Navie_Bayes.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()

# %%
plt.plot([1,2,3],[4,5,6])
plt.title('Sample Table')
plt.xlabel('X')
plt.ylabel('Y')
plt.show()

# %%
arr = np.array([1,2,3,4,5])
print(np.mean(arr))
# Out:
# 3.0

# %%
data = np.random.normal(loc=0, scale=1, size=1000)
sns.histplot(data, bins=30, kde=True)
plt.title("Histogram for normally distributed data")
plt.xlabel("Value")
plt.ylabel("Frequency")
plt.show()
